# %%
import requests

url = 'https://www.n2yo.com/sat/instant-tracking.php?s=28654&hlat=30.3545&hlng=76.3702&d=300&r=189658935294.26416&tz=GMT+05:30&O=n2yocom&rnd_str=41b2ccf92dbc7f5ca02e5fb0773d2f8b&callback='

headers = {
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'Accept-Encoding': 'gzip, deflate, br, zstd',
    'Accept-Language': 'en-GB,en-US;q=0.9,en;q=0.8',
    'Cache-Control': 'max-age=0',
    'Connection': 'keep-alive',
    'Cookie': 'bfp_sn_rf_8b2087b102c9e3e5ffed1c1478ed8b78=Direct; bafpCS=170625661977532440838034; bafp=5986a3d0-bc22-11ee-aa11-e723a0e50353; bfp_sn_rt_8b2087b102c9e3e5ffed1c1478ed8b78=1706273312432; selectionCenteredMode=true; _gid=GA1.2.520995157.1720160867; strSatList=28654; PHPSESSID=022f29b9b5c8a4990d08cb519bae4e2a; __gads=ID=ccfbb2e22e5073bf:T=1719815595:RT=1720349053:S=ALNI_MZRyAVR6y97TlRYQtLET4g0Q_Lykg; __gpi=UID=00000e6d7fc67ce9:T=1719815595:RT=1720349053:S=ALNI_MZsH9Rx9TT8cogggrnEGWQ9pgOaJQ; __eoi=ID=5f6507b750639a9f:T=1719815595:RT=1720349053:S=AA-AfjZ4QDWoCTEjry9prTIX1wWt; _ga_QZGWPSKPV5=GS1.1.1720349019.24.1.1720349346.0.0.0; _ga=GA1.2.1240810803.1706191103; FCNEC=%5B%5B%22AKsRol_Qq6ZEX6iuip0sEBR3RgGPDIj-UjV0gwnQ9KxmGEvYWf-_7Vnz6Y62MQYbbfSrz12oyWK3MKRs5HHYVCrvSWMYbPPofvQK7BWk9KbsDNvsr2BeRpv1I3wnckW3vGLQ0pjNaSxMVIV52L3ygcefZnsAN2DjTA%3D%3D%22%5D%5D',
    'Host': 'www.n2yo.com',
    'Sec-Fetch-Dest': 'document',
    'Sec-Fetch-Mode': 'navigate',
    'Sec-Fetch-Site': 'none',
    'Sec-Fetch-User': '?1',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36 OPR/109.0.0.0 (Edition std-1)',
    'sec-ch-ua': '"Opera GX";v="109", "Not:A-Brand";v="8", "Chromium";v="123"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"'
}

def fetch_data():
    response = requests.get(url, headers=headers)
    response.raise_for_status() 
    return response.json()

def parse_position_data(position_data):
    most_recent_entry = position_data[0]['d']
    fields = most_recent_entry.split('|')
    parsed_entry = {
        'latitude': fields[0],
        'longitude': fields[1],
        'azimuth': fields[2],
        'elevation': fields[3]
    }
    return parsed_entry

# %%
parsed_position = []
try:
    while True:
        data = fetch_data()
        if data:
            for entry in data:
                id = entry['id']
                positions = entry['pos']
                parsed_position.append(parse_position_data(positions))
except KeyboardInterrupt:
    print(parsed_position)
# Out:
# [{'latitude': '55.19710712', 'longitude': '82.98365307', 'azimuth': '8.89', 'elevation': '3.14'}, {'latitude': '55.08394070', 'longitude': '82.92012877', 'azimuth': '8.86', 'elevation': '3.27'}, {'latitude': '54.97074545', 'longitude': '82.85691384', 'azimuth': '8.84', 'elevation': '3.40'}, {'latitude': '54.85752618', 'longitude': '82.79400787', 'azimuth': '8.82', 'elevation': '3.54'}, {'latitude': '54.80090675', 'longitude': '82.76266935', 'azimuth': '8.81', 'elevation': '3.60'}, {'latitude': '54.68764846', 'longitude': '82.70021939', 'azimuth': '8.79', 'elevation': '3.74'}, {'latitude': '54.57436216', 'longitude': '82.63806858', 'azimuth': '8.77', 'elevation': '3.87'}, {'latitude': '54.46105265', 'longitude': '82.57621657', 'azimuth': '8.74', 'elevation': '4.01'}, {'latitude': '54.34771786', 'longitude': '82.51465929', 'azimuth': '8.72', 'elevation': '4.15'}, {'latitude': '54.29104106', 'longitude': '82.48399030', 'azimuth': '8.71', 'elevation': '4.21'}, {'latitude': '54.17766651', 'longitude': '82.42286868', 'azimuth': '8.68', 'elevation': '4.35'}, {'latitude': '54.06426951', 'longitude': '82.36203612', 'azimuth': '8.66', 'elevation': '4.49'}, {'latitude': '53.95084801', 'longitude': '82.30148870', 'azimuth': '8.64', 'elevation': '4.63'}, {'latitude': '53.83739993', 'longitude': '82.24122253', 'azimuth': '8.61', 'elevation': '4.77'}, {'latitude': '53.72393006', 'longitude': '82.18123741', 'azimuth': '8.59', 'elevation': '4.91'}, {'latitude': '53.66718615', 'longitude': '82.15134897', 'azimuth': '8.58', 'elevation': '4.98'}, {'latitude': '53.55368054', 'longitude': '82.09177872', 'azimuth': '8.55', 'elevation': '5.12'}, {'latitude': '53.44014907', 'longitude': '82.03248066', 'azimuth': '8.53', 'elevation': '5.26'}, {'latitude': '53.32659652', 'longitude': '81.97345463', 'azimuth': '8.50', 'elevation': '5.41'}, {'latitude': '53.26981154', 'longitude': '81.94404241', 'azimuth': '8.49', 'elevation': '5.48'}, {'latitude': '53.15622432', 'longitude': '81.88541797', 'azimuth': '8.46', 'elevation': '5.62'}, {'latitude': '53.04261193', 'longitude': '81.82705702', 'azimuth': '8.43', 'elevation': '5.77'}, {'latitude': '52.92897914', 'longitude': '81.76895947', 'azimuth': '8.41', 'elevation': '5.91'}, {'latitude': '52.81532386', 'longitude': '81.71112175', 'azimuth': '8.38', 'elevation': '6.06'}, {'latitude': '52.70164628', 'longitude': '81.65354148', 'azimuth': '8.35', 'elevation': '6.21'}, {'latitude': '52.58794658', 'longitude': '81.59621633', 'azimuth': '8.32', 'elevation': '6.35'}, {'latitude': '52.53108621', 'longitude': '81.56764755', 'azimuth': '8.31', 'elevation': '6.43'}, {'latitude': '52.41735368', 'longitude': '81.51070073', 'azimuth': '8.28', 'elevation': '6.58'}, {'latitude': '52.30359949', 'longitude': '81.45400328', 'azimuth': '8.25', 'elevation': '6.73'}, {'latitude': '52.18982382', 'longitude': '81.39755296', 'azimuth': '8.22', 'elevation': '6.88'}, {'latitude': '52.13292569', 'longitude': '81.36941864', 'azimuth': '8.21', 'elevation': '6.95'}, {'latitude': '52.01911813', 'longitude': '81.31333483', 'azimuth': '8.18', 'elevation': '7.11'}, {'latitude': '51.90528952', 'longitude': '81.25749263', 'azimuth': '8.15', 'elevation': '7.26'}, {'latitude': '51.79144003', 'longitude': '81.20188987', 'azimuth': '8.12', 'elevation': '7.41'}, {'latitude': '51.67756755', 'longitude': '81.14652331', 'azimuth': '8.09', 'elevation': '7.57'}, {'latitude': '51.62062474', 'longitude': '81.11892891', 'azimuth': '8.07', 'elevation': '7.65'}, {'latitude': '51.50672381', 'longitude': '81.06391546', 'azimuth': '8.04', 'elevation': '7.80'}, {'latitude': '51.39280259', 'longitude': '81.00913408', 'azimuth': '8.01', 'elevation': '7.96'}, {'latitude': '51.27886124', 'longitude': '80.95458271', 'azimuth': '7.98', 'elevation': '8.12'}, {'latitude': '51.16489763', 'longitude': '80.90025822', 'azimuth': '7.95', 'elevation': '8.28'}, {'latitude': '51.10790953', 'longitude': '80.87318139', 'azimuth': '7.93', 'elevation': '8.36'}, {'latitude': '50.99391 ...

# %%
import pandas as pd
TrackingInfo = pd.DataFrame(parsed_position)
TrackingInfo.to_csv("TrackingInfo.csv")

# %%
TrackingInfo
# Out:
#         latitude    longitude azimuth elevation
# 0    55.19710712  82.98365307    8.89      3.14
# 1    55.08394070  82.92012877    8.86      3.27
# 2    54.97074545  82.85691384    8.84      3.40
# 3    54.85752618  82.79400787    8.82      3.54
# 4    54.80090675  82.76266935    8.81      3.60
# ..           ...          ...     ...       ...
# 501   2.36128591  66.63516941  200.18     -1.15
# 502   2.30294051  66.62192562  200.17     -1.21
# 503   2.18625450  66.59544136  200.15     -1.32
# 504   2.06956864  66.56895997  200.13     -1.44
# 505   1.95288294  66.54248132  200.11     -1.55
#
# [506 rows x 4 columns]

# %%
# https://api.n2yo.com/rest/v1/satellite/positions/28654/30.3545/76.3702/0/780/&apiKey=Z6EQ6H-4N8XFH-PEXWAK-5A57
