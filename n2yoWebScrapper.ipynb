# %%
import requests
import json
import time

url = 'https://www.n2yo.com/sat/instant-tracking.php?s=28654&hlat=31.63306&hlng=74.86556&d=300&r=722117850527.586&tz=GMT+05:30&O=n2yocom&rnd_str=96b00f1ecf86aa6cdd13b6c4df5de0c5&callback='

headers = {
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'Accept-Encoding': 'gzip, deflate, br, zstd',
    'Accept-Language': 'en-GB,en-US;q=0.9,en;q=0.8',
    'Cache-Control': 'max-age=0',
    'Connection': 'keep-alive',
    'Cookie': 'bfp_sn_rf_8b2087b102c9e3e5ffed1c1478ed8b78=Direct; bafpCS=170625661977532440838034; bafp=5986a3d0-bc22-11ee-aa11-e723a0e50353; bfp_sn_rt_8b2087b102c9e3e5ffed1c1478ed8b78=1706273312432; selectionCenteredMode=true; _gid=GA1.2.520995157.1720160867; strSatList=28654; PHPSESSID=022f29b9b5c8a4990d08cb519bae4e2a; __gads=ID=ccfbb2e22e5073bf:T=1719815595:RT=1720349053:S=ALNI_MZRyAVR6y97TlRYQtLET4g0Q_Lykg; __gpi=UID=00000e6d7fc67ce9:T=1719815595:RT=1720349053:S=ALNI_MZsH9Rx9TT8cogggrnEGWQ9pgOaJQ; __eoi=ID=5f6507b750639a9f:T=1719815595:RT=1720349053:S=AA-AfjZ4QDWoCTEjry9prTIX1wWt; _ga_QZGWPSKPV5=GS1.1.1720349019.24.1.1720349346.0.0.0; _ga=GA1.2.1240810803.1706191103; FCNEC=%5B%5B%22AKsRol_Qq6ZEX6iuip0sEBR3RgGPDIj-UjV0gwnQ9KxmGEvYWf-_7Vnz6Y62MQYbbfSrz12oyWK3MKRs5HHYVCrvSWMYbPPofvQK7BWk9KbsDNvsr2BeRpv1I3wnckW3vGLQ0pjNaSxMVIV52L3ygcefZnsAN2DjTA%3D%3D%22%5D%5D',
    'Host': 'www.n2yo.com',
    'Sec-Fetch-Dest': 'document',
    'Sec-Fetch-Mode': 'navigate',
    'Sec-Fetch-Site': 'none',
    'Sec-Fetch-User': '?1',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36 OPR/109.0.0.0 (Edition std-1)',
    'sec-ch-ua': '"Opera GX";v="109", "Not:A-Brand";v="8", "Chromium";v="123"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"'
}

def fetch_data():
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status() 
        data = response.json() 
        return data
    except requests.exceptions.RequestException as e:
        print(f"Request failed: {e}")
        return None

try:
    while True:
        data = fetch_data()
        if data:
        
            print(json.dumps(data, indent=2)) 
        time.sleep(1) 
except KeyboardInterrupt:
    print("Scraping stopped by user")
# Out:
# [
#   {
#     "id": "28654",
#     "pos": [
#       {
#         "d": "-60.02880189|119.48266616|159.06|-46.27|15.55786083|-68.35771730|868.05|0|28654|1720367158|1||||"
#       },
#       {
#         "d": "-59.97301818|119.44251466|159.05|-46.24|15.47282988|-68.36557623|868.02|7.5133424086638|28654|1720367159|1||||"
#       },
#       {
#         "d": "-59.91722392|119.40248370|159.03|-46.20|15.38772496|-68.37338380|867.99|7.513461470249|28654|1720367160|1||||"
#       },
#       {
#         "d": "-59.86141916|119.36257262|159.01|-46.17|15.30254638|-68.38113991|867.96|7.5134777910271|28654|1720367161|1||||"
#       },
#       {
#         "d": "-59.80560397|119.32278077|158.99|-46.14|15.21729446|-68.38884451|867.93|7.5135957413943|28654|1720367162|1||||"
#       },
#       {
#         "d": "-59.74977614|119.28310593|158.97|-46.11|15.13196609|-68.39649780|867.91|7.5139142591611|28654|1720367163|1||||"
#       },
#       {
# ...

# %%
import requests

url = 'https://www.n2yo.com/sat/instant-tracking.php?s=28654&hlat=31.63306&hlng=74.86556&d=300&r=722117850527.586&tz=GMT+05:30&O=n2yocom&rnd_str=96b00f1ecf86aa6cdd13b6c4df5de0c5&callback='

headers = {
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'Accept-Encoding': 'gzip, deflate, br, zstd',
    'Accept-Language': 'en-GB,en-US;q=0.9,en;q=0.8',
    'Cache-Control': 'max-age=0',
    'Connection': 'keep-alive',
    'Cookie': 'bfp_sn_rf_8b2087b102c9e3e5ffed1c1478ed8b78=Direct; bafpCS=170625661977532440838034; bafp=5986a3d0-bc22-11ee-aa11-e723a0e50353; bfp_sn_rt_8b2087b102c9e3e5ffed1c1478ed8b78=1706273312432; selectionCenteredMode=true; _gid=GA1.2.520995157.1720160867; strSatList=28654; PHPSESSID=022f29b9b5c8a4990d08cb519bae4e2a; __gads=ID=ccfbb2e22e5073bf:T=1719815595:RT=1720349053:S=ALNI_MZRyAVR6y97TlRYQtLET4g0Q_Lykg; __gpi=UID=00000e6d7fc67ce9:T=1719815595:RT=1720349053:S=ALNI_MZsH9Rx9TT8cogggrnEGWQ9pgOaJQ; __eoi=ID=5f6507b750639a9f:T=1719815595:RT=1720349053:S=AA-AfjZ4QDWoCTEjry9prTIX1wWt; _ga_QZGWPSKPV5=GS1.1.1720349019.24.1.1720349346.0.0.0; _ga=GA1.2.1240810803.1706191103; FCNEC=%5B%5B%22AKsRol_Qq6ZEX6iuip0sEBR3RgGPDIj-UjV0gwnQ9KxmGEvYWf-_7Vnz6Y62MQYbbfSrz12oyWK3MKRs5HHYVCrvSWMYbPPofvQK7BWk9KbsDNvsr2BeRpv1I3wnckW3vGLQ0pjNaSxMVIV52L3ygcefZnsAN2DjTA%3D%3D%22%5D%5D',
    'Host': 'www.n2yo.com',
    'Sec-Fetch-Dest': 'document',
    'Sec-Fetch-Mode': 'navigate',
    'Sec-Fetch-Site': 'none',
    'Sec-Fetch-User': '?1',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36 OPR/109.0.0.0 (Edition std-1)',
    'sec-ch-ua': '"Opera GX";v="109", "Not:A-Brand";v="8", "Chromium";v="123"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"'
}

def fetch_data():
    response = requests.get(url, headers=headers)
    response.raise_for_status() 
    return response.json()

def parse_position_data(position_data):
    most_recent_entry = position_data[0]['d']
    fields = most_recent_entry.split('|')
    parsed_entry = {
        'latitude': fields[0],
        'longitude': fields[1],
        'azimuth': fields[2],
        'elevation': fields[3]
    }
    return parsed_entry

data = fetch_data()
if data:
    for entry in data:
        id = entry['id']
        positions = entry['pos']
        parsed_position = parse_position_data(positions)
import requests

url = 'https://www.n2yo.com/sat/instant-tracking.php?s=28654&hlat=30.3545&hlng=76.3702&d=300&r=189658935294.26416&tz=GMT+05:30&O=n2yocom&rnd_str=41b2ccf92dbc7f5ca02e5fb0773d2f8b&callback='

headers = { 
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'Accept-Encoding': 'gzip, deflate, br, zstd',
    'Accept-Language': 'en-GB,en-US;q=0.9,en;q=0.8',
    'Cache-Control': 'max-age=0',
    'Connection': 'keep-alive',
    'Cookie': 'bfp_sn_rf_8b2087b102c9e3e5ffed1c1478ed8b78=Direct; bafpCS=170625661977532440838034; bafp=5986a3d0-bc22-11ee-aa11-e723a0e50353; bfp_sn_rt_8b2087b102c9e3e5ffed1c1478ed8b78=1706273312432; selectionCenteredMode=true; _gid=GA1.2.520995157.1720160867; strSatList=28654; PHPSESSID=022f29b9b5c8a4990d08cb519bae4e2a; __gads=ID=ccfbb2e22e5073bf:T=1719815595:RT=1720349053:S=ALNI_MZRyAVR6y97TlRYQtLET4g0Q_Lykg; __gpi=UID=00000e6d7fc67ce9:T=1719815595:RT=1720349053:S=ALNI_MZsH9Rx9TT8cogggrnEGWQ9pgOaJQ; __eoi=ID=5f6507b750639a9f:T=1719815595:RT=1720349053:S=AA-AfjZ4QDWoCTEjry9prTIX1wWt; _ga_QZGWPSKPV5=GS1.1.1720349019.24.1.1720349346.0.0.0; _ga=GA1.2.1240810803.1706191103; FCNEC=%5B%5B%22AKsRol_Qq6ZEX6iuip0sEBR3RgGPDIj-UjV0gwnQ9KxmGEvYWf-_7Vnz6Y62MQYbbfSrz12oyWK3MKRs5HHYVCrvSWMYbPPofvQK7BWk9KbsDNvsr2BeRpv1I3wnckW3vGLQ0pjNaSxMVIV52L3ygcefZnsAN2DjTA%3D%3D%22%5D%5D',
    'Host': 'www.n2yo.com',
    'Sec-Fetch-Dest': 'document',
    'Sec-Fetch-Mode': 'navigate',
    'Sec-Fetch-Site': 'none',
    'Sec-Fetch-User': '?1',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36 OPR/109.0.0.0 (Edition std-1)',
    'sec-ch-ua': '"Opera GX";v="109", "Not:A-Brand";v="8", "Chromium";v="123"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"'
}

def fetch_data():
    response = requests.get(url, headers=headers)
    response.raise_for_status() 
    return response.json()

def parse_position_data(position_data):
    most_recent_entry = position_data[0]['d']
    fields = most_recent_entry.split('|')
    parsed_entry = {
        'latitude': fields[0],
        'longitude': fields[1],
        'azimuth': fields[2],
        'elevation': fields[3]
    }
    return parsed_entry

# %%
data = fetch_data()
if data:
    for entry in data:
        id = entry['id']
        positions = entry['pos']
        parsed_position = parse_position_data(positions)

parsed_position
# Out:
# {'latitude': '-34.32810677',
#  'longitude': '83.03793585',
#  'azimuth': '173.89',
#  'elevation': '-26.74'}

# %%
# https://www.n2yo.com/sat/instant-tracking.php?s=33591&hlat=30.32667&hlng=76.40028&d=300&r=919328617851.3535&tz=GMT+05:30&O=n2yocom&rnd_str=9f55a48e6e064dc1ab37f808d071192f&callback=

# %%
import requests

url = 'https://www.n2yo.com/sat/instant-tracking.php?s=28654&hlat=31.63306&hlng=74.86556&d=300&r=722117850527.586&tz=GMT+05:30&O=n2yocom&rnd_str=96b00f1ecf86aa6cdd13b6c4df5de0c5&callback='

headers = {
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'Accept-Encoding': 'gzip, deflate, br, zstd',
    'Accept-Language': 'en-GB,en-US;q=0.9,en;q=0.8',
    'Cache-Control': 'max-age=0',
    'Connection': 'keep-alive',
    'Cookie': 'bfp_sn_rf_8b2087b102c9e3e5ffed1c1478ed8b78=Direct; bafpCS=170625661977532440838034; bafp=5986a3d0-bc22-11ee-aa11-e723a0e50353; bfp_sn_rt_8b2087b102c9e3e5ffed1c1478ed8b78=1706273312432; selectionCenteredMode=true; _gid=GA1.2.520995157.1720160867; strSatList=28654; PHPSESSID=022f29b9b5c8a4990d08cb519bae4e2a; __gads=ID=ccfbb2e22e5073bf:T=1719815595:RT=1720349053:S=ALNI_MZRyAVR6y97TlRYQtLET4g0Q_Lykg; __gpi=UID=00000e6d7fc67ce9:T=1719815595:RT=1720349053:S=ALNI_MZsH9Rx9TT8cogggrnEGWQ9pgOaJQ; __eoi=ID=5f6507b750639a9f:T=1719815595:RT=1720349053:S=AA-AfjZ4QDWoCTEjry9prTIX1wWt; _ga_QZGWPSKPV5=GS1.1.1720349019.24.1.1720349346.0.0.0; _ga=GA1.2.1240810803.1706191103; FCNEC=%5B%5B%22AKsRol_Qq6ZEX6iuip0sEBR3RgGPDIj-UjV0gwnQ9KxmGEvYWf-_7Vnz6Y62MQYbbfSrz12oyWK3MKRs5HHYVCrvSWMYbPPofvQK7BWk9KbsDNvsr2BeRpv1I3wnckW3vGLQ0pjNaSxMVIV52L3ygcefZnsAN2DjTA%3D%3D%22%5D%5D',
    'Host': 'www.n2yo.com',
    'Sec-Fetch-Dest': 'document',
    'Sec-Fetch-Mode': 'navigate',
    'Sec-Fetch-Site': 'none',
    'Sec-Fetch-User': '?1',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36 OPR/109.0.0.0 (Edition std-1)',
    'sec-ch-ua': '"Opera GX";v="109", "Not:A-Brand";v="8", "Chromium";v="123"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"'
}

def fetch_data():
    response = requests.get(url, headers=headers)
    response.raise_for_status() 
    return response.json()

def parse_position_data(position_data):
    most_recent_entry = position_data[0]['d']
    fields = most_recent_entry.split('|')
    parsed_entry = {
        'latitude': fields[0],
        'longitude': fields[1],
        'azimuth': fields[2],
        'elevation': fields[3]
    }
    return parsed_entry

# %%
parsed_position = []
try:
    while True:
        data = fetch_data()
        if data:
            for entry in data:
                id = entry['id']
                positions = entry['pos']
                parsed_position.append(parse_position_data(positions))
except KeyboardInterrupt:
    print(parsed_position)
# Out:
# [{'latitude': '16.66455949', 'longitude': '-108.20687764', 'azimuth': '3.93', 'elevation': '-64.18'}, {'latitude': '16.72314083', 'longitude': '-108.22097161', 'azimuth': '3.94', 'elevation': '-64.15'}, {'latitude': '16.84030352', 'longitude': '-108.24917830', 'azimuth': '3.97', 'elevation': '-64.08'}, {'latitude': '16.95746068', 'longitude': '-108.27740882', 'azimuth': '4.00', 'elevation': '-64.02'}, {'latitude': '17.01603806', 'longitude': '-108.29153329', 'azimuth': '4.01', 'elevation': '-63.99'}, {'latitude': '17.13319041', 'longitude': '-108.31980081', 'azimuth': '4.04', 'elevation': '-63.92'}, {'latitude': '17.25034187', 'longitude': '-108.34809383', 'azimuth': '4.06', 'elevation': '-63.86'}, {'latitude': '17.30891520', 'longitude': '-108.36224946', 'azimuth': '4.08', 'elevation': '-63.83'}, {'latitude': '17.42605939', 'longitude': '-108.39057969', 'azimuth': '4.10', 'elevation': '-63.77'}, {'latitude': '17.54320026', 'longitude': '-108.41893539', 'azimuth': '4.13', 'elevation'
# ...

# %%
import pandas as pd
TrackingInfo = pd.DataFrame(parsed_position)
TrackingInfo.to_csv("TrackingInfo.csv")
